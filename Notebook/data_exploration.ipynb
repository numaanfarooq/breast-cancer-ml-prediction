# %% [markdown]
# #Goal and objective of data_exploration
#
# Understand the structure, identify the missing values, and gain insights into the data's characteristics.
# Display summary statistics, visualize distributions of variables, explore relationships between variables, and identify any patterns or trends in the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Data/dataR2.csv")

# %%
df.head(2)
# Out:
#    Age        BMI  Glucose  Insulin      HOMA  Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409  8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897  8.8438     5.429285   4.06405
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1

# %%
df.isnull().sum()
# Out:
# Age               0
# BMI               0
# Glucose           0
# Insulin           0
# HOMA              0
# Leptin            0
# Adiponectin       0
# Resistin          0
# MCP.1             0
# Classification    0
# dtype: int64

# %%
df['Classification'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df.columns
# Out:
# Index(['Age', 'BMI', 'Glucose', 'Insulin', 'HOMA', 'Leptin', 'Adiponectin',
#        'Resistin', 'MCP.1', 'Classification'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             116 non-null    int64
#  1   BMI             116 non-null    float64
#  2   Glucose         116 non-null    int64
#  3   Insulin         116 non-null    float64
#  4   HOMA            116 non-null    float64
#  5   Leptin          116 non-null    float64
#  6   Adiponectin     116 non-null    float64
#  7   Resistin        116 non-null    float64
#  8   MCP.1           116 non-null    float64
#  9   Classification  116 non-null    int64
# dtypes: float64(7), int64(3)
# memory usage: 9.2 KB

# %% [markdown]
# #Insights
#
# Data Size:- The dataset has 116 rows(enteries) and 10 columns
#
# Data Type:- The dataType in the dataset is numerical with both descrete and continuous values (float and int)
#
# There are no missing values in the dataset
#
# Our target variable is Classification

# %%
df.describe()
# Out:
#               Age         BMI     Glucose     Insulin        HOMA      Leptin  \
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean    57.301724   27.582111   97.793103   10.012086    2.694988   26.615080
# std     16.112766    5.020136   22.525162   10.067768    3.642043   19.183294
# min     24.000000   18.370000   60.000000    2.432000    0.467409    4.311000
# 25%     45.000000   22.973205   85.750000    4.359250    0.917966   12.313675
# 50%     56.000000   27.662416   92.000000    5.924500    1.380939   20.271000
# 75%     71.000000   31.241442  102.000000   11.189250    2.857787   37.378300
# max     89.000000   38.578759  201.000000   58.460000   25.050342   90.280000
#
#        Adiponectin    Resistin        MCP.1  Classification
# count   116.000000  116.000000   116.000000      116.000000
# mean     10.180874   14.725966   534.647000        1.551724
# std       6.843341   12.390646   345.912663        0.499475
# ...

# %% [markdown]
# Age:
#
# Mean age: 57.30 years
# Age range: 24 to 89 years
# BMI (Body Mass Index):
#
# Mean BMI: 27.58 kg/m²
# BMI range: 18.37 to 38.58 kg/m²
# Glucose:
#
# Mean glucose level: 97.79 mg/dL
# Glucose range: 60 to 201 mg/dL
# Insulin:
#
# Mean insulin level: 10.01 µU/mL
# Insulin range: 2.43 to 58.46 µU/mL
# HOMA (Homeostatic Model Assessment):
#
# Mean HOMA value: 2.69
# HOMA range: 0.47 to 25.05
# Leptin, Adiponectin, Resistin, and MCP.1:
#
# These variables represent hormone and protein levels in the blood.
#
# Classification:
#
# Indicates healthy controls (1) or patients with breast cancer (2)
# Roughly equal number of healthy controls and breast cancer patients, with a mean value of approximately 1.55
# T

# %%
plt.figure(figsize=(20, 20))
df.hist(bins=20, color='blue', edgecolor='red', linewidth=1.0, xlabelsize=10, ylabelsize=10)
plt.tight_layout()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("General Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'General Correlation Matrix')

# %%
df.corr(method='pearson')
# Out:
#                      Age       BMI   Glucose   Insulin      HOMA    Leptin  \
# Age             1.000000  0.008530  0.230106  0.032495  0.127033  0.102626
# BMI             0.008530  1.000000  0.138845  0.145295  0.114480  0.569593
# Glucose         0.230106  0.138845  1.000000  0.504653  0.696212  0.305080
# Insulin         0.032495  0.145295  0.504653  1.000000  0.932198  0.301462
# HOMA            0.127033  0.114480  0.696212  0.932198  1.000000  0.327210
# Leptin          0.102626  0.569593  0.305080  0.301462  0.327210  1.000000
# Adiponectin    -0.219813 -0.302735 -0.122121 -0.031296 -0.056337 -0.095389
# Resistin        0.002742  0.195350  0.291327  0.146731  0.231101  0.256234
# MCP.1           0.013462  0.224038  0.264879  0.174356  0.259529  0.014009
# Classification -0.043555 -0.132586  0.384315  0.276804  0.284012 -0.001078
#
#                 Adiponectin  Resistin     MCP.1  Classification
# Age               -0.219813  0.002742  0.013462       -0.043555
# ...
